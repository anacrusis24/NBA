# %%
# NBA
import nba_api as nba
from nba_api.stats.static import players
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import boxscoretraditionalv2

# General
import pandas as pd
import numpy as np

# %%
# box = boxscoretraditionalv2.BoxScoreTraditionalV2.get_normalized_dict('0022101220')   #get_available_data(game_id='0022101220')
box = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id = '0022101220')

# %%
df = box.get_data_frames()[0]
# df2 = box.get_available_data()

print(df.columns)
df
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   0022101220  1610612747               LAL  Los Angeles    1630559
# 1   0022101220  1610612747               LAL  Los Angeles    1626169
# 2   0022101220  1610612747               LAL  Los Angeles    1629117
# 3   0022101220  1610612747               LAL  Los Angeles    1628370
# 4   0022101220  1610612747               LAL  Los Angeles    1629659
# 5   0022101220  1610612747               LAL  Los Angeles     201571
# 6   0022101220  1610612747               LAL  Los Angeles    1630222
# 7   0022101220  1610612747               LAL  Los Angeles     201961
# ...
